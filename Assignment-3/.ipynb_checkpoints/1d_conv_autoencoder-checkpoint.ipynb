# %%
import pandas as pd
import numpy as np 
import random
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import accuracy_score
import scipy.io
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Conv2DTranspose

# %%
pd.set_option('display.max_rows', 5100)
pd.set_option('display.max_columns', 5010)
pd.set_option('display.width', 10100)

# %%
data_orig=scipy.io.loadmat('data_for_cnn.mat')
data_orig=pd.DataFrame(data_orig['ecg_in_window'])
target=scipy.io.loadmat('class_label.mat')
target=pd.DataFrame(target['label'])

# %%
def normalize(X):
    return (X-X.mean())/X.std()

# %%
data=normalize(data_orig)

# %%
plt.figure(figsize=(30,20))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.plot(data.iloc[i,:].values)
    plt.xlabel(target.iloc[i,:].values.flatten())
plt.show()
# Out:
# C:\Users\anura\Anaconda3\envs\assignment3\lib\site-packages\matplotlib\text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
plt.figure(figsize=(30,20))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.plot(data.iloc[len(data)-i-1,:].values)
    plt.xlabel(target.iloc[len(data)-i-1,:].values.flatten())
plt.show()

# %%
class CrossValidation:
    def __init__(self,kind='holdout',seed=2010):
        self.kind=kind
        np.random.seed(seed)
        
    def train_test_split(self,X,y,train_per=False,n_folds=False):
        if self.kind=='holdout':
            train_rows=random.sample(range(0,y.size),train_per*y.size//100)
            train_rows.sort()
            test_rows=[rows for rows in X.index.values if rows not in train_rows]
            
            return X.iloc[train_rows].values,y.iloc[train_rows].values,X.iloc[test_rows].values,y.iloc[test_rows].values
        elif self.kind=='fold':
            
            total=random.sample(range(0,y.size),y.size)
            train_rows=[]
            test_rows=[]
            for i in range(n_folds):
                test_selected_row=total[y.size//n_folds*i:y.size//n_folds*(i+1)]
                test_rows.append(test_selected_row)
                test_rows[i].sort()
                train_rows.append([row for row in total if row not in test_selected_row])
                train_rows[i].sort()
            return train_rows,test_rows

# %%
cv=CrossValidation(kind='holdout')
train_X,train_y,test_X,test_y=cv.train_test_split(data,target,train_per=70)

# %%
train_X=np.expand_dims(train_X,2)
test_X=np.expand_dims(test_X,2)

# %%
# def Conv1DTranspose(input_tensor, filters, kernel_size, strides=2, padding='same'):
#     x = layers.Lambda(lambda x: K.expand_dims(x, axis=2))(input_tensor)
#     x = Conv2DTranspose(filters=filters, kernel_size=(kernel_size, 1), strides=(strides, 1), padding=padding)(x)
#     x = layers.Lambda(lambda x: K.squeeze(x, axis=2))(x)
#     return x

# %%
model=models.Sequential()
model.add(layers.Conv1D(filters=8, kernel_size=2,input_shape=(1000, 1),strides=4,activation='relu'))
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Dense(16))
model.add(layers.Lambda(lambda x: K.expand_dims(x, axis=2)))
model.add(layers.Conv2DTranspose(filters=8,kernel_size=1,strides=1))
model.add(layers.Reshape((1000,1)))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_1 (Conv1D)            (None, 250, 8)            24
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 125, 8)            0
# _________________________________________________________________
# dense (Dense)                (None, 125, 16)           144
# _________________________________________________________________
# lambda (Lambda)              (None, 125, 1, 16)        0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 125, 1, 8)         136
# _________________________________________________________________
# reshape (Reshape)            (None, 1000, 1)           0
# ...
# Total params: 304
# Trainable params: 304
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy')

# %%
model.fit(train_X,train_X,validation_data=(test_X,test_X),epochs=100,batch_size=100);
# Out:
# Train on 700 samples, validate on 300 samples
# Epoch 1/100
# 100/700 [===>..........................] - ETA: 29s
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-15-2bdc14855036> in <module>
# ----> 1 model.fit(train_X,train_X,validation_data=(test_X,test_X),epochs=100,batch_size=100);
#
# ~\Anaconda3\envs\assignment3\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ...

# %%
y_pred=model.predict(test_X).reshape(-1,1000)

# %%
plt.subplot(1,2,1)
plt.plot(y_pred[0].reshape(-1,1))
plt.subplot(1,2,2)
plt.plot(test_X[0])
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(y_pred[1].reshape(-1,1))
plt.subplot(1,2,2)
plt.plot(test_X[1])
plt.show()

# %%
y_pred[0].shape
# Out:
# (1000,)

# %%
NUM_OF_FIGS=10
plt.figure(figsize=(30,20))
for i in range(1,NUM_OF_FIGS):
    plt.subplot(NUM_OF_FIGS,2,2*i-1)
    plt.plot(y_pred[i].reshape(-1,1),color='blue')
#     plt.ylim([-1,1])
    plt.subplot(NUM_OF_FIGS,2,2*i)
    plt.plot(test_X[i],color='green')
#     plt.ylim([-1,1])
plt.show()
